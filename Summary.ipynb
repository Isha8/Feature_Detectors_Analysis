# %% [markdown]
# * Summary
#
#     Feature matching of two images using SIFT, SURF, BRIEF and ORB feature descriptors for matching features of the two images using the brute force matcher of OpenCV. The results of the comparison can be seen as screenshots of the outputs of the four different features' matching.

# %%
from IPython.display import Image
Image(filename='SIFT_matching.jpg')

# %%
from IPython.display import Image
Image(filename='SURF_matching.jpg')

# %%
from IPython.display import Image
Image(filename='BRIEF_matching.jpg')

# %%
from IPython.display import Image
Image(filename='ORB_matching.jpg')
